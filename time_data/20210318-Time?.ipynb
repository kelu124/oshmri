# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
filepath = "200917175808 - Raw data.txt"

# %%
f = open(filepath, "r")
data = f.read()

# %%
data = [complex(x.strip()) for x in data.replace("(","").replace(")","").split("\n ")]
data
# Out:
# [0j,
#  (-4.76837158203125e-06-1.7881393432617188e-05j),
#  (-2.86102294921875e-06+1.7642974853515625e-05j),
#  (-1.2636184692382812e-05+5.9604644775390625e-06j),
#  (-1.4781951904296875e-05+4.5299530029296875e-06j),
#  (7.152557373046875e-06-1.430511474609375e-06j),
#  (1.4066696166992188e-05-1.6450881958007812e-05j),
#  (1.430511474609375e-05+8.58306884765625e-06j),
#  (2.0503997802734375e-05-1.0967254638671875e-05j),
#  (-7.62939453125e-06-1.9073486328125e-05j),
#  (-1.239776611328125e-05+9.5367431640625e-06j),
#  (-3.5762786865234375e-06-1.0251998901367188e-05j),
#  (3.5762786865234375e-06-1.2159347534179688e-05j),
#  (-3.0994415283203125e-06-2.2172927856445312e-05j),
#  (1.1444091796875e-05-1.52587890625e-05j),
#  (1.7881393432617188e-05+1.71661376953125e-05j),
#  (-3.0994415283203125e-06-3.075599670410156e-05j),
#  (-3.337860107421875e-06-1.9550323486328125e-05j),
#  (4.76837158203125e-06-9.059906005859375e-06j),
#  (1.4781951904296875e-05-8.344650268554688e-06j),
# ...

# %%
plt.plot(np.log(np.abs(data)))
# Out:
# /home/kelu/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in log
#   """Entry point for launching an IPython kernel.
